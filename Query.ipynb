# %%
import pandas as pd
import matplotlib.pyplot as plt
import wbgapi as wb

def get_data(indicator, label):
    inflation = wb.data.DataFrame(indicator, wb.region.members('ECS'), time=range(2000,2024))
    inflation.to_csv(f"{label}.csv")
    print(inflation)

get_data('FP.CPI.TOTL.ZG', 'inflation')
get_data('NE.IMP.GNFS.ZS', 'imports')
get_data('NE.CON.TOTL.ZS', 'consumption')
# Out:
#              YR2000     YR2001     YR2002     YR2003     YR2004     YR2005  \
# economy
# ALB        0.050018   3.107588   7.770526   0.484003   2.280019   2.366582
# AND             NaN        NaN        NaN        NaN        NaN        NaN
# ARM       -0.790884   3.145905   1.060049   4.721553   6.961261   0.638928
# AUT        2.344863   2.650001   1.810358   1.355554   2.061206   2.299138
# AZE        1.805003   1.547196   2.771165   2.233865   6.708930   9.679507
# BEL        2.544518   2.469258   1.645214   1.588964   2.097283   2.781433
# BGR       10.316262   7.360939   5.810144   2.348642   6.147131   5.038838
# BIH             NaN        NaN        NaN        NaN        NaN        NaN
# BLR      168.620236  61.134933  42.537548  28.397840  18.108242  10.338879
# CHE        1.558529   0.989020   0.642712   0.638273   0.802909   1.171954
# CHI             NaN        NaN        NaN        NaN        NaN        NaN
# ...
